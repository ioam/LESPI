# %%
import topo.analysis
import featuremapper.analysis.pinwheels

from IPython.display import HTML
import holoviews as hv
# %load_ext holoviews.ipython
# Out:
# The holoviews.ipython extension is already loaded. To reload it, use:
#   %reload_ext holoviews.ipython

# %%
HTML('<img src="figures/LGN_Diagram.svg" width=500/>')
# Out:
# <img src="figures/LGN_Diagram.svg" width=500/>

# %% [markdown]
# # SCAL

# %%
HTML('<img src="figures/SCAL_Diagram.svg" width=400/>')
# Out:
# <img src="figures/SCAL_Diagram.svg" width=400/>

# %%
HTML('<img src="figures/Sceniak_Center.png" width=400 style="float: left"/>'
     '<img src="figures/Sceniak_Surround.png" width=400/>')
# Out:
# <img src="figures/Sceniak_Center.png" width=400 style="float: left"/><img src="figures/Sceniak_Surround.png" width=400/>

# %%
# %%output size=150 dpi=300 fig='svg'
# %%opts Histogram (edgecolor='k' facecolor='white') Overlay [yaxis=None show_frame=False aspect=1.5]
# %%opts Layout [sublabel_position=(-0.2, 0.8) aspect_weight=1 hspace=0]
# hv.Store.load(open('SCAL/SCAL_SizeTuning.pkl', 'rb'))()
# Out:
# :Layout
#    .Overlay.Size_tuning_center   :Overlay
#       .Histogram.I :Histogram   [$r_c$]   (Frequency)
#       .Arrow.I     :Arrow   [x,y]
#    .Overlay.Size_tuning_surround :Overlay
#       .Histogram.I :Histogram   [$r_s$]   (Frequency)
#       .Arrow.I     :Arrow   [x,y]

# %%
HTML('<img src="figures/Tailby_SI.png" width=400/>')
# Out:
# <img src="figures/Tailby_SI.png" width=400/>

# %%
# %%output dpi=120 size=120
# %%opts Histogram {+axiswise} Text {+axiswise} Overlay [aspect=1.5]
# hv.Store.load(open('SCAL/SCAL_Surround.pkl', 'rb'))()
# Out:
# :Layout
#    .Suppression_Index.I                   :Overlay
#       .Suppression_Index.I :Histogram   [SI]   (Frequency)
#       .Text.I              :Text   [x,y]
#    .Contrast_Size_Tuning_Shift.I          :HoloMap   [Time]
#       :Overlay
#          .Contrast_Size_Tuning_Shift.I :Histogram   [CSS]   (Frequency)
#          .Text.I                       :Text   [x,y]
#    .Overlay.Orientation_Contrast_Analysis :Overlay
#       .Histogram.Orientation_Contrast_Analysis :Histogram   [OCSI]   (Frequency)
#       .Text.I                                  :Text   [x,y]

# %%
# %%output size=200 dpi=100
# %%opts Layout [vspace=0.2 hspace=0.15] Bounds (color='black')
# %%opts AdjointLayout [border_size=0.05]
# %%opts Overlay [sublabel_position=(-0.2, 0.9)]
# %%opts HeatMap [sublabel_position=(-0.2, 0.9)] (cmap='RdBu_r' clims=(1.64, 4.64))
# hv.Store.load(open('SCAL/SCAL_Robustness.pkl', 'rb'))()
# Out:
# /exports/work/inf_ndtc/s1048519/tools/.virtualenvs/topo/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:598: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
# :Layout
#    .PinwheelAnalysis.V1 :AdjointLayout
#       :Overlay
#          .Orientation_Preference.V1 :Image   [x,y]   (Orientation Preference)
#          .Real.V1                   :Contours   [x,y]
#          .Imaginary.V1              :Contours   [x,y]
#          .Pinwheels.V1              :Points   [x,y]
#       :GridSpace   [X,Y]
#          :HoloMap   [contrast,latexc_strength,Time]
#             :Overlay
#                .OnOff_CFs.LGNOnAfferent :CFView   [x,y]   (z)
#    .Pinwheel_Density.I  :HeatMap   [latexc_strength,contrast]   ($
# ho$)

# %% [markdown]
# # SEPI

# %%
HTML('<img src="figures/SEPI_Diagram.svg" width=800/>')
# Out:
# <img src="figures/SEPI_Diagram.svg" width=800/>

# %%
# %%output size=150 dpi=300 fig='svg'
# %%opts Histogram (edgecolor='k' facecolor='white') Overlay [yaxis=None show_frame=False aspect=1.5]
# %%opts Layout [sublabel_position=(-0.2, 0.8) aspect_weight=1 hspace=0]
# hv.Store.load(open('sepi/SEPI_SizeTuning.pkl', 'rb'))()
# Out:
# :Layout
#    .Overlay.Size_tuning_center   :Overlay
#       .Histogram.I :Histogram   [$r_c$]   (Frequency)
#       .Arrow.I     :Arrow   [x,y]
#    .Overlay.Size_tuning_surround :Overlay
#       .Histogram.I :Histogram   [$r_s$]   (Frequency)
#       .Arrow.I     :Arrow   [x,y]

# %%
# %%output dpi=120 size=120
# %%opts Histogram {+axiswise} Text {+axiswise} Overlay [aspect=1.5]
# hv.Store.load(open('sepi/SEPI_Spatial.pkl', 'rb'))()
# Out:
# :Layout
#    .Suppression_Index.I                   :Overlay
#       .Suppression_Index.I :Histogram   [SI]   (Frequency)
#       .Text.I              :Text   [x,y]
#    .Contrast_Size_Tuning_Shift.I          :HoloMap   [locexc_strength,contrast,Time]
#       :Overlay
#          .Contrast_Size_Tuning_Shift.I :Histogram   [CSS]   (Frequency)
#          .Text.I                       :Text   [x,y]
#    .Overlay.Orientation_Contrast_Analysis :Overlay
#       .Histogram.Orientation_Contrast_Analysis :Histogram   [OCSI]   (Frequency)
#       .Text.I                                  :Text   [x,y]

# %%
# %%output size=200 dpi=100
# %%opts Layout [vspace=0.2 hspace=0.15] Bounds (color='black')
# %%opts AdjointLayout [border_size=0.05]
# %%opts Overlay [sublabel_position=(-0.2, 0.9)]
# %%opts HeatMap [sublabel_position=(-0.2, 0.9)] (cmap='RdBu_r' clims=(1.64, 4.64))
# hv.Store.load(open('sepi/SEPI_Robustness.pkl', 'rb'))()
# Out:
# :Layout
#    .PinwheelAnalysis.V1Exc :AdjointLayout
#       :Overlay
#          .Orientation_Preference.V1Exc :Image   [x,y]   (Orientation Preference)
#          .Real.V1Exc                   :Contours   [x,y]
#          .Imaginary.V1Exc              :Contours   [x,y]
#          .Pinwheels.V1Exc              :Points   [x,y]
#       :GridSpace   [X,Y]
#          :HoloMap   [contrast,latexc_strength,Time]
#             :Overlay
#                .CF_Weight.LGNOnAfferent  :CFView   [x,y]   (z)
#                .CF_Weight.LGNOffAfferent :CFView   [x,y]   (z)
#    .Pinwheel_Density.I     :HeatMap   [latexc_strength,contrast]   ($
# ho$)

# %%
# %%output size=200 dpi=100 fig='svg'
# %%opts Layout [hspace=0.25]
# %%opts HeatMap [sublabel_position=(-0.2, 0.9) sublabel_size=24 fontsize={'title':24,'xlabel':18,'ylabel':18,'ticks':18}]
# %%opts HeatMap.Pinwheel_Density (clims=(1.64, 4.64))
# hv.Store.load(open('sepi/SEPI_Linearity.pkl', 'rb'))()
# Out:
# :Layout
#    .Stability.I                   :HeatMap   [pv_timeconstant,pv_exponent]   (Similarity)
#    .Orientation_Selectivity.V1Exc :HeatMap   [pv_timeconstant,pv_exponent]   (Selectivity)
#    .Pinwheel_Density.I            :HeatMap   [pv_timeconstant,pv_exponent]   ($
# ho$)

# %% [markdown]
# # LESPI

# %%
HTML('<img src="figures/LESPI_Diagram.svg" width=800/>')
# Out:
# <img src="figures/LESPI_Diagram.svg" width=800/>

# %%
# %%output size=150 dpi=300 fig='svg'
# %%opts Histogram (edgecolor='k' facecolor='white') Overlay [yaxis=None show_frame=False aspect=1.5]
# %%opts Layout [sublabel_position=(-0.2, 0.8) aspect_weight=1 hspace=0]
# hv.Store.load(open('lespi/LESPI_SizeTuning.pkl', 'rb'))()
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .Histogram.I :Histogram   [$r_c$]   (Frequency)
#       .Arrow.I     :Arrow   [x,y]
#    .Overlay.II :Overlay
#       .Histogram.I :Histogram   [$r_s$]   (Frequency)
#       .Arrow.I     :Arrow   [x,y]

# %%
# %%output dpi=120 size=120
# %%opts Histogram {+axiswise} Text {+axiswise} Overlay [aspect=1.5]
# hv.Store.load(open('lespi/LESPI_Spatial.pkl', 'rb'))()
# Out:
# :Layout
#    .Suppression_Index.I                   :Overlay
#       .Suppression_Index.I :Histogram   [SI]   (Frequency)
#       .Text.I              :Text   [x,y]
#    .Contrast_Size_Tuning_Shift.I          :HoloMap   [Index,Time]
#       :Overlay
#          .Contrast_Size_Tuning_Shift.I :Histogram   [CSS]   (Frequency)
#          .Text.I                       :Text   [x,y]
#    .Overlay.Orientation_Contrast_Analysis :Overlay
#       .Histogram.Orientation_Contrast_Analysis :Histogram   [OCSI]   (Frequency)
#       .Text.I                                  :Text   [x,y]

# %%
# %%output size=200 dpi=100
# %%opts Layout [vspace=0.2 hspace=0.15] Bounds (color='black')
# %%opts AdjointLayout [border_size=0.05]
# %%opts Overlay [sublabel_position=(-0.2, 0.9)]
# %%opts HeatMap [sublabel_position=(-0.2, 0.9)] (cmap='RdBu_r' clims=(1.64, 4.64))
# hv.Store.load(open('lespi/LESPI_Robustness.pkl', 'rb'))()
# Out:
# :Layout
#    .PinwheelAnalysis.V1Exc :AdjointLayout
#       :Overlay
#          .Orientation_Preference.V1Exc :Image   [x,y]   (Orientation Preference)
#          .Real.V1Exc                   :Contours   [x,y]
#          .Imaginary.V1Exc              :Contours   [x,y]
#          .Pinwheels.V1Exc              :Points   [x,y]
#       :GridSpace   [X,Y]
#          :HoloMap   [contrast,latexc_strength,Index,Time]
#             :Overlay
#                .OnOff_CFs.LGNOnAfferent :CFView   [x,y]   (z)
#    .Pinwheel_Density.I     :HeatMap   [latexc_strength,contrast]   ($
# ho$)

# %% [markdown]
# ### Overview

# %% [markdown]
# |Measurement name  | Cat      |  Macaque   | SCAL | SEPI | LESPI |
# |------------------|----------|------------|------|------|-------|
# |Suppression index |0.16      |0.44        |0.149 |0.258 |0.349  |
# |CSS               |1.33/1.36 |2.3/2.1/2.5 |1.108 |1.04  |1.05   |
# |OCSI              |-0.25     |-1.7        |-1.7  |0.842 |-0.643 |
